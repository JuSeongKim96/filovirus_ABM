# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
interval = 48
pos = []
for i in range(1,5):
    pos.append(interval*i-i)


for y,j in enumerate(pos):
    print(y+1,j)
# Out:
# 1 47
# 2 94
# 3 141
# 4 188

# %%
def f(df, label, color):
    df.drop(['Unnamed: 0','zero'], axis=1, inplace=True)
    e_col = []
    for i in df:
        if 'e' in i:
            e_col.append(i)

    mean_list = df[e_col].mean(axis=1)
    std_list = df[e_col].std(axis=1)
    
    return plt.errorbar(df['x1'], mean_list,std_list,marker='o', label=label,capsize=3, color=color, alpha=0.4) , std_list

# %%
# plaque_list = ['2NPC1','Y420S', 'P424A', 'S425L', 'D502E','D508N']
# colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown']

plaque_list = ['2NPC1','Y420S', 'P424A', 'D502E','D508N', ]
colors = ['blue', 'orange', 'green', 'purple', 'brown']

for i in range(len(plaque_list)):
    df = pd.read_csv(f'../result/beta_fit/data/Zaire_{plaque_list[i]}_total_48_csg3.csv')
    plt.figure(figsize=(8,5))
    plt.tick_params(axis='both', which='major', labelsize=15)
    plot,std_list = f(df, plaque_list[i], color=colors[i])
    # print(std_list, i)
    plt.legend()

# %%
df = pd.read_csv(f'../result/beta_fit/data/Angola_Y420S_total.csv')
df.drop(['Unnamed: 0','zero'], axis=1, inplace=True)

e_col = []
for i in df:
    if 'e' in i:
        e_col.append(i)

mean_list = df[e_col].mean(axis=1)
std_list = df[e_col].std(axis=1)

# %%
std_list.mean()
# Out:
# 0.06412313448588926

# %%
Zaire_2NPC1 = {0.20:	0.360010,
0.21:	0.446326,
0.22:	0.434877,	
0.23:	0.302384,	
0.24:	0.380132,	
0.25:	0.373765,	
0.26:	0.324714,	
0.27:	0.340208,	
0.28:	0.276550,	
0.29:	0.405819,
0.30:	0.476686,	
0.31:	0.483224,	
0.32:	0.378565,	
0.33:	0.663117,	
0.34:	0.555394}


plt.figure()

lists = sorted(Zaire_2NPC1.items()) # sorted by key, return a list of tuples
x, y = zip(*lists)
plt.plot(x, y)
plt.xlabel(r'$\beta$', fontsize=20)
plt.ylabel('error',fontsize=20)
plt.show()

print(f'Zaire_2NPC1  beta : {list(Zaire_2NPC1.keys())[np.argmin(list(Zaire_2NPC1.values()))]:.3f}')
# Out:
# Zaire_2NPC1  beta : 0.280

# %%
df = pd.read_csv(f'../result/beta_fit/data/Angola_2NPC1_total_49_csg222.csv')
df.drop(['Unnamed: 0', 'zero'], axis=1, inplace=True)
df.columns = ['x','y']

plt.plot(df['x'],df['y'])
print('Angola 2NPC1 beta :',df['x'][np.argmin(df['y'])])
# Out:
# Angola 2NPC1 beta : 0.34

# %%
Zaire_Y420S = {0.15: 0.7451997932399964,
 0.16: 0.7768595825165032,
 0.17: 0.861384626835235,
 0.18000000000000002: 0.6154158888992763,
 0.19000000000000003: 0.6045747169804072,
 0.20000000000000004: 0.5024522089154749,
 0.21000000000000005: 0.4760522330364333,
 0.22000000000000006: 0.4754339786105334,
 0.23000000000000007: 0.48707359602031153,
 0.24000000000000007: 0.49297152171927705,
 0.2500000000000001: 0.47603789722656664,
 0.2600000000000001: 0.46613083588560045,
 0.27000000000000013: 0.47380355980919,
 0.28000000000000014: 0.4503885514751924,
 0.29000000000000015: 0.47666611190493313}
 
plt.figure()

lists = sorted(Zaire_Y420S.items()) # sorted by key, return a list of tuples
x, y = zip(*lists)
plt.plot(x, y)
plt.xlabel(r'$\beta$', fontsize=20)
plt.ylabel('error',fontsize=20)
plt.show()
print(f'Zaire_Y420S  beta : {list(Zaire_Y420S.keys())[np.argmin(list(Zaire_Y420S.values()))]:.3f}')
# Out:
# Zaire_Y420S  beta : 0.280

# %%
Angola_Y420S = {0.45: 0.600815854989335,
 0.46: 0.6776830986360904,
 0.47000000000000003: 0.6963274473444282,
 0.48000000000000004: 0.6906728488262235,
 0.49000000000000005: 0.7037853221561263,
 0.5: 0.5933109868132651,
 0.51: 0.6114923735706816,
 0.52: 0.7127128986988687,
 0.53: 0.6009238803864847,
 0.54: 0.6106443852009853,
 0.55: 0.6884586704830217}

plt.figure()

lists = sorted(Angola_Y420S.items()) # sorted by key, return a list of tuples
x, y = zip(*lists)
plt.plot(x, y)
plt.xlabel(r'$\beta$', fontsize=20)
plt.ylabel('error',fontsize=20)
plt.show()
print(f'Angola_Y420S  beta : {list(Angola_Y420S.keys())[np.argmin(list(Angola_Y420S.values()))]:.3f}')
# Out:
# Angola_Y420S  beta : 0.500

# %%
Zaire_P424A = {0.05: 1.2906133988790893,
 0.060000000000000005: 0.896712257529607,
 0.07: 0.8167021349323238,
 0.08000000000000002: 0.589905199276074,
 0.09000000000000001: 0.5924031579374196,
 0.1: 0.4318428624576609,
 0.11000000000000001: 0.41481454107966403,
 0.12000000000000001: 0.4967667796244897,
 0.13: 0.49835230531951036,
 0.14: 0.5099309179577232,
 0.15000000000000002: 0.550363892655498,
 0.16000000000000003: 0.5528781859027795,
 0.17000000000000004: 0.5808782771970084,
 0.18000000000000005: 0.6395072430335005,
 0.19: 0.7591620544756045,
 0.2: 0.7304931332452905}

plt.figure()

lists = sorted(Zaire_P424A.items()) # sorted by key, return a list of tuples
x, y = zip(*lists)
plt.plot(x, y)
plt.xlabel(r'$\beta$', fontsize=20)
plt.ylabel('error',fontsize=20)
plt.show()
print(f'Zaire_P424A beta : {list(Zaire_P424A.keys())[np.argmin(list(Zaire_P424A.values()))]:.3f}')
# Out:
# Zaire_P424A beta : 0.110

# %%
Angola_P424A = {0.3: 1.0334152149159448,
 0.31: 1.0605203613455625,
 0.32: 1.2618621771525378,
 0.33: 1.0948901591996045,
 0.34: 1.0365129055007416,
 0.35000000000000003: 1.0291811946386864,
 0.36000000000000004: 0.9706146002899457,
 0.37000000000000005: 1.0957605324728856,
 0.38000000000000006: 1.0663874666513666,
 0.39000000000000007: 0.9308275806760468,
 0.4000000000000001: 0.8973698370015019,
 0.4100000000000001: 0.9976108115291745,
 0.4200000000000001: 0.973119643088981,
 0.4300000000000001: 0.9505438801611804,
 0.4400000000000001: 0.8824018955707403,
 0.4500000000000001: 0.9932657636876391}


plt.figure()

lists = sorted(Angola_P424A.items()) # sorted by key, return a list of tuples
x, y = zip(*lists)
plt.plot(x, y, label='')
plt.xlabel(r'$\beta$', fontsize=20)
plt.ylabel('error',fontsize=20)
plt.show()
print(f'Angola_P424A beta : {list(Angola_P424A.keys())[np.argmin(list(Angola_P424A.values()))]:.3f}')
# Out:
# Angola_P424A beta : 0.440

# %%
Zaire_S425L = {0.05: 1.2898561260565065,
 0.060000000000000005: 1.1224837231554519,
 0.07: 0.8840270734758687,
 0.08000000000000002: 0.7904120706120464,
 0.09000000000000001: 0.6196136407049871,
 0.1: 0.48601529899518714,
 0.11000000000000001: 0.5639936074570105,
 0.12000000000000001: 0.3802461629810677,
 0.13: 0.39989245468079704,
 0.14: 0.3801516446184987,
 0.15000000000000002: 0.443328341528338,
 0.16000000000000003: 0.5074988099796157,
 0.17000000000000004: 0.4985247541245188,
 0.18000000000000005: 0.5412771960874669,
 0.19: 0.603586694487632,
 0.2: 0.6044625785666592}


plt.figure()

lists = sorted(Zaire_S425L.items()) # sorted by key, return a list of tuples
x, y = zip(*lists)
plt.plot(x, y)
plt.xlabel(r'$\beta$', fontsize=20)
plt.ylabel('error',fontsize=20)
plt.show()

print(f'Zaire_S425L beta : {list(Zaire_S425L.keys())[np.argmin(list(Zaire_S425L.values()))]:.3f}')
# Out:
# Zaire_S425L beta : 0.140

# %%
Angola_S425L = {0.25: 0.5379879292427889,
 0.26: 0.5539861129083593,
 0.27: 0.5118485695413396,
 0.28: 0.5703082502144917,
 0.29000000000000004: 0.4733288080207265,
 0.30000000000000004: 0.4470731536325323,
 0.31000000000000005: 0.44804486105952,
 0.32000000000000006: 0.5069162984885696,
 0.33000000000000007: 0.49946948947884295,
 0.3400000000000001: 0.4804213884556353,
 0.3500000000000001: 0.49896324990899343,
 0.3600000000000001: 0.4826990747029505,
 0.3700000000000001: 0.48206249886214625,
 0.3800000000000001: 0.5533499481062598,
 0.3900000000000001: 0.5542537171475564,
 0.40000000000000013: 0.6980145325002374,
 0.41000000000000014: 0.8465549576052022,
 0.42000000000000015: 0.5234036877362414,
 0.43000000000000016: 0.745833457536511,
 0.44000000000000017: 0.6398536853145377}


plt.figure()

lists = sorted(Angola_S425L.items()) # sorted by key, return a list of tuples
x, y = zip(*lists)
plt.plot(x, y)
plt.xlabel(r'$\beta$', fontsize=20)
plt.ylabel('error',fontsize=20)
plt.show()

print(f'Angola_S425L beta : {list(Angola_S425L.keys())[np.argmin(list(Angola_S425L.values()))]:.3f}')
# Out:
# Angola_S425L beta : 0.300

# %%
df = pd.read_csv(f'../result/beta_fit/data/Zaire_D502E_total_49_csg222.csv')
df.drop(['Unnamed: 0', 'zero'], axis=1, inplace=True)
df.columns = ['x','y']

plt.plot(df['x'],df['y'])


print('Angola 2NPC1 beta :',df['x'][np.argmin(df['y'])])
# Out:
# Angola 2NPC1 beta : 0.2199999999999999

# %%
df = pd.read_csv(f'../result/beta_fit/data/Zaire_D508N_total_49_csg222.csv')
df.drop(['Unnamed: 0', 'zero'], axis=1, inplace=True)
df.columns = ['x','y']

plt.plot(df['x'],df['y'])

print('Angola 2NPC1 beta :',df['x'][np.argmin(df['y'])])
# Out:
# Angola 2NPC1 beta : 0.1699999999999999

# %%
df = pd.read_csv(f'../result/beta_fit/data/Angola_D508N_total_49_csg222.csv')
df.drop(['Unnamed: 0', 'zero'], axis=1, inplace=True)
df.columns = ['x','y']

plt.plot(df['x'],df['y'])

print('Angola 2NPC1 beta :',df['x'][np.argmin(df['y'])])
# Out:
# Angola 2NPC1 beta : 0.3100000000000001

# %%
df = pd.read_csv(f'../result/beta_fit/data/Angola_D502E_total_49_csg222.csv')
df.drop(['Unnamed: 0', 'zero'], axis=1, inplace=True)
df.columns = ['x','y']

plt.plot(df['x'],df['y'])


print('Angola_D502E beta :',df['x'][np.argmin(df['y'])])
# Out:
# Angola_D502E beta : 0.3700000000000001

# %%
# Zaire
# 2NPC1 0.07775710896526533
# Y420S 0.08976786103427699
# P424A 0.0953900639941096
# D502E 0.08055768866045321
# D508N 0.09140431157838716
# S425L 0.08007618650438948

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

snp_list = ['P424A', 'S425L', 'D508N','D502E','2NPC1' ,'Y420S']

beta1 = np.zeros(6)
beta1[0] =0.11
beta1[1] =0.14
beta1[2] =0.17
beta1[3] =0.22
beta1[4] =0.25
beta1[5] =0.28


y_tick = [0,0.2,0.4,0.6,0.8,1,1.2,1.4,1.6]

std_list=[0.0953900639941096,0.08007618650438948,0.09140431157838716,0.08055768866045321,0.07775710896526533,0.08976786103427699]


plt.figure(figsize=(12,8))
plots = sns.barplot(x=snp_list, y=beta1/0.25, color='red', alpha=0.5, )
plots.set_yticklabels(y_tick,size = 25)
plots.set_xticklabels(snp_list,size = 25)
plt.ylabel(r'$\frac{\beta_i}{\beta_{2NPC1}}$', fontsize=40)

plt.ylim(0,1.7)

plt.errorbar([0,1,2,3,4,5],beta1/0.25, std_list, linestyle='None', color='black', markersize=5, capsize=5, capthick=5, elinewidth=5)

# Iterating over the bars one-by-one
for bar in plots.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=20, xytext=(0, 40),
                   textcoords='offset points')
# Out:
# /var/folders/7w/f3yz5lls31n4jsq13_dmd6z40000gn/T/ipykernel_85145/2314985296.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plots.set_yticklabels(y_tick,size = 25)

# %%
# Angola 

# 2NPC1 0.0721
# P424A 0.0891
# D502E 0.082
# D508N 0.069
# Y420S 0.06412313448588926
# S425L 0.08374444696606587

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

snp_list = [ 'S425L','D508N','D502E' ,'2NPC1','P424A','Y420S']

beta1 = np.zeros(6)
beta1[0] =0.3
beta1[1] =0.31
beta1[2] =0.37
beta1[3] =0.40
beta1[4] =0.44
beta1[5] =0.5

std_list=[0.08374444696606587,
0.069,
0.082,
0.07798824549099138,
0.0879988373499925,
0.06412313448588926]


y_tick = [0,0.2,0.4,0.6,0.8,1,1.2,1.4,1.6]
plt.figure(figsize=(12,8))
plots = sns.barplot(x=snp_list, y=beta1/0.4, color='blue', alpha=0.5, )
plots.set_yticklabels(y_tick,size = 25)
plots.set_xticklabels(snp_list,size = 25)

plt.ylabel(r'$\frac{\beta_i}{\beta_{2NPC1}}$', fontsize=40)

plt.errorbar([0,1,2,3,4,5],beta1/0.4, std_list, linestyle='None', color='black', markersize=5, capsize=5,capthick=5, elinewidth=5)

plt.ylim(0,1.7)
# Iterating over the bars one-by-one
for bar in plots.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=20, xytext=(0, 40),
                   textcoords='offset points')
# Out:
# /var/folders/7w/f3yz5lls31n4jsq13_dmd6z40000gn/T/ipykernel_85145/2331928946.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plots.set_yticklabels(y_tick,size = 25)

# %%
path = '../data/'

im_path = '../data/Figure/'
plaque = pd.read_excel(path + 'plaque_processed.xlsx')
plaque.fillna(method='ffill', inplace=True)
df = plaque.groupby(['Virus','Day','SNPs'])

# 그룹별 데이터프레임을 생성 후 dict에 저장
output = dict(list(df))
output.keys()

day_list = ['Day2', 'Day3', 'Day4', 'Day5', 'Day6']
plaque_list = ['2NPC1','Y420S', 'P424A', 'S425L', 'D502E','D508N']

def S_type(virus:str,Day : str):
    temp = pd.DataFrame()
    for i in plaque_list:
        temp = pd.concat([temp, output[(virus, Day, i)]])
    return temp

def D_type(virus, snps):
    temp = pd.DataFrame()
    for i in day_list:
        temp = pd.concat([temp, output[(virus,i , snps)]])
    return temp

# %%
v_type = 'Zaire'
s_type = '2NPC1'

df = D_type(v_type, s_type)
df['Radius [mm]'] = np.sqrt(df['Size [sqmm]'] / np.pi)

r_list = []
sd_list = []

for k in day_list:
    r_list.append(df[df['Day']==k]['Radius [mm]'].mean())
    sd_list.append(df[df['Day']==k]['Radius [mm]'].sem())
